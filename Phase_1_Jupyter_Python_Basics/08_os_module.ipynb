# %%
import os

# %%
dir(os)
# Out:
# ['DirEntry',
#  'EX_OK',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk_symlinks_as_files',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
# ...

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01_basic_python_exercises.ipynb',
#  '02_conditions_loops.ipynb',
#  '03_functions.ipynb',
#  '04_importing_exporting.ipynb',
#  '05_variable_scope.ipynb',
#  '06_comprehensions.ipynb',
#  '07_sorting.ipynb',
#  '08_os_module.ipynb',
#  'my_module.py',
#  '__pycache__']

# %%
os.mkdir('os_module')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01_basic_python_exercises.ipynb',
#  '02_conditions_loops.ipynb',
#  '03_functions.ipynb',
#  '04_importing_exporting.ipynb',
#  '05_variable_scope.ipynb',
#  '06_comprehensions.ipynb',
#  '07_sorting.ipynb',
#  '08_os_module.ipynb',
#  'my_module.py',
#  'os_module',
#  '__pycache__']

# %%
os.makedirs('os_module/test/1')
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01_basic_python_exercises.ipynb',
#  '02_conditions_loops.ipynb',
#  '03_functions.ipynb',
#  '04_importing_exporting.ipynb',
#  '05_variable_scope.ipynb',
#  '06_comprehensions.ipynb',
#  '07_sorting.ipynb',
#  '08_os_module.ipynb',
#  'my_module.py',
#  'os_module',
#  '__pycache__']

# %%
os.rmdir('os_module/test')
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01_basic_python_exercises.ipynb',
#  '02_conditions_loops.ipynb',
#  '03_functions.ipynb',
#  '04_importing_exporting.ipynb',
#  '05_variable_scope.ipynb',
#  '06_comprehensions.ipynb',
#  '07_sorting.ipynb',
#  '08_os_module.ipynb',
#  'my_module.py',
#  'os_module',
#  '__pycache__']

# %%
os.removedirs('os_module')
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01_basic_python_exercises.ipynb',
#  '02_conditions_loops.ipynb',
#  '03_functions.ipynb',
#  '04_importing_exporting.ipynb',
#  '05_variable_scope.ipynb',
#  '06_comprehensions.ipynb',
#  '07_sorting.ipynb',
#  '08_os_module.ipynb',
#  'my_module.py',
#  '__pycache__']

# %%
os.stat('my_module.py')
# Out:
# os.stat_result(st_mode=33206, st_ino=47569271064189470, st_dev=17217352424186092705, st_nlink=1, st_uid=0, st_gid=0, st_size=256, st_atime=1769858280, st_mtime=1769858040, st_ctime=1769857856)

# %%
os.stat('my_module.py').st_size
# Out:
# 256

# %%
from datetime import datetime
mod_time = os.stat('my_module.py').st_mtime # last modification
mod_time # 1769858040.8203545

datetime.fromtimestamp(mod_time) # datetime.datetime(2026, 1, 31, 13, 14, 0, 820354)
# Out:
# datetime.datetime(2026, 1, 31, 13, 14, 0, 820354)

# %%
for dirpath, dirnames, filenames in os.walk(os.getcwd()):
    print(dirpath)
    print(dirnames)
    print(filenames)
# Out:
# C:\Users\Maryam\OneDrive\Desktop\4th_Level\Courses\Coursera\data-science-projects\Data_Science_Journey\Phase_1_Jupyter_Python_Basics
# ['.ipynb_checkpoints', '__pycache__']
# ['01_basic_python_exercises.ipynb', '02_conditions_loops.ipynb', '03_functions.ipynb', '04_importing_exporting.ipynb', '05_variable_scope.ipynb', '06_comprehensions.ipynb', '07_sorting.ipynb', '08_os_module.ipynb', 'my_module.py']
# C:\Users\Maryam\OneDrive\Desktop\4th_Level\Courses\Coursera\data-science-projects\Data_Science_Journey\Phase_1_Jupyter_Python_Basics\.ipynb_checkpoints
# []
# ['01_basic_python_exercises-checkpoint.ipynb', '02_conditions_loops-checkpoint.ipynb', '03_functions-checkpoint.ipynb', '04_importing_exporting-checkpoint.ipynb', '05_variable_scope-checkpoint.ipynb', '06_comprehensions-checkpoint.ipynb', '07_sorting-checkpoint.ipynb', '08_os_module-checkpoint.ipynb', 'my_module-checkpoint.py']
# ...

# %%
dir(os.path)
# Out:
# ['_LCMAP_LOWERCASE',
#  '_LCMapStringEx',
#  '_LOCALE_NAME_INVARIANT',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_findfirstfile',
#  '_get_bothseps',
#  '_getfinalpathname',
#  '_getfinalpathname_nonstrict',
#  '_getfullpathname',
#  '_getvolumepathname',
#  '_isreservedname',
#  '_nt_readlink',
#  '_path_isdevdrive',
#  '_readlink_deep',
#  '_reserved_chars',
#  '_reserved_names',
#  'abspath',
#  'altsep',
#  'basename',
#  'commonpath',
#  'commonprefix',
#  'curdir',
#  'defpath',
#  'devnull',
#  'dirname',
#  'exists',
#  'expanduser',
#  'expandvars',
#  'extsep',
#  'genericpath',
#  'getatime',
#  'getctime',
#  'getmtime',
#  'getsize',
#  'isabs',
#  'isdevdrive',
#  'isdir',
#  'isfile',
#  'isjunction',
#  'islink',
#  'ismount',
#  'isreserved',
#  'join',
#  'lexists',
#  'normcase',
#  'normpath',
#  'os',
#  'pardir',
#  'pathsep',
#  'realpath',
#  'relpath',
#  'samefile',
# ...
