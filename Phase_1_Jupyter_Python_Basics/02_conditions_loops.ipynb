# %%
# conditions
# if
if True:
    'Maryam'

if False:
    'Skaik'

name = 'Maryam'
if name == 'Maryam':
    'Correct name'
else:
    'Wrong name'

name = 'Refaa'
if name == 'Maryam':
    'Correct name'
elif name == 'Refaa':
    "Correct father's name"
else:
    'Wrong name'

# and, or, not
user = 'Admin'
logged_in = True

if user == 'Admin' and logged_in:
    'Admin Page'

logged_in = False

if user == 'Admin' or logged_in:
    'Admin Page'

logged_in = False

if not logged_in:
    'login'

# use is
a = [1, 2, 3]
b = [1, 2, 3]

a == b # True

a is b # False
# this because a and b in different memory location
id(a) # 2087423970368
id(b) # 2087424325952


# False values in pythin
# False
# None
# Zero of any numeric type
# Any empty sequence, for example: '', (), []
# Any empty mapping, for example: {}
# Out:
# 2087418756160

# %%
# loops
nums = [1, 2, 3, 4, 5]

for num in nums:
    if num == 3:
        break

for num in nums:
    if num == 3:
        continue

# nested loops
for num in nums:
    for letter in 'maryam':
        num, letter

for i in range(10):
    i # print from 0 to 9

for i in range(1, 11):
    i # print from 1 to 10

x = 1
while x < 10:
    if x == 5:
        break
    x += 1

x # 5
# Out:
# 5
