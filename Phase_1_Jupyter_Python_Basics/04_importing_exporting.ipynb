# %%
# importing from same folder
import my_module as mm
# also can write
from my_module import find_index as fi, test

from my_module import *

# %%
courses = ['DS', 'DB', 'WD', 'AI']

index = mm.find_index(courses, 'AI')
index # 3
# Out:
# 3

# %%
index = find_index(courses, 'AI')
index # 3
# Out:
# 3

# %%
test # 'Testing string'
# Out:
# 'Testing string'

# %%
index = fi(courses, 'AI')
index # 3
# Out:
# 3

# %%
import sys
sys.path
# Out:
# ['C:\\Python313\\python313.zip',
#  'C:\\Python313\\DLLs',
#  'C:\\Python313\\Lib',
#  'C:\\Python313',
#  '',
#  'C:\\Users\\Maryam\\AppData\\Roaming\\Python\\Python313\\site-packages',
#  'C:\\Python313\\Lib\\site-packages']

# %%
import random

random_course = random.choice(courses)
random_course # 'DS'
# Out:
# 'AI'

# %%
import math
rads = math.radians(90)
rads # 1.5707963267948966
# Out:
# 1.5707963267948966

# %%
import datetime
import calendar

today = datetime.date.today()
today # datetime.date(2026, 1, 31)

calendar.isleap(2023) # False
calendar.isleap(2020) # True
# Out:
# True

# %%
import os
os.getcwd() # return path of this file
