# %%
person = {
    "first": "Maryam", 
    "last": "Skaik", 
    "email": "MaryamSkaik@gmail.com"
}

# %%
people = {
    "first": ["Maryam"], 
    "last": ["Skaik"], 
    "email": ["MaryamSkaik@gmail.com"]
}

# %%
people = {
    "first": ["Maryam", 'Tia', 'Tima'], 
    "last": ["Skaik", 'lulu', 'lulu'], 
    "email": ["MaryamSkaik@gmail.com", 'Tialulu@email.com', 'Timalulu@email.com']
}

# %%
people['email']
# Out:
# ['MaryamSkaik@gmail.com', 'Tialulu@email.com', 'Timalulu@email.com']

# %%
# make a dataframe from dictionary
import pandas as pd

# %%
df = pd.DataFrame(people)
df
# Out:
#     first   last                  email
# 0  Maryam  Skaik  MaryamSkaik@gmail.com
# 1     Tia   lulu      Tialulu@email.com
# 2    Tima   lulu     Timalulu@email.com

# %%
df['last']
# Out:
# 0    Skaik
# 1     lulu
# 2     lulu
# Name: last, dtype: object

# %%
type(df['last'])
# Out:
# pandas.core.series.Series

# %%
# Series: is list of data, have an index

# %%
df.email
# Out:
# 0    MaryamSkaik@gmail.com
# 1        Tialulu@email.com
# 2       Timalulu@email.com
# Name: email, dtype: object

# %%
# if I want a list of values, so pass a list
df[['last','email']]
# Out:
#     last                  email
# 0  Skaik  MaryamSkaik@gmail.com
# 1   lulu      Tialulu@email.com
# 2   lulu     Timalulu@email.com

# %%
# to got columns
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
# to got rows, we use loc, and iloc  functions
# iloc: give it the index
df.iloc[0] # return the first row
# Out:
# first                   Maryam
# last                     Skaik
# email    MaryamSkaik@gmail.com
# Name: 0, dtype: object

# %%
# same if we want a list of values, we pass a list of indices
df.iloc[[0,1]]
# Out:
#     first   last                  email
# 0  Maryam  Skaik  MaryamSkaik@gmail.com
# 1     Tia   lulu      Tialulu@email.com

# %%
# also we can specify the columns we want also by it's index
df.iloc[[0,1], 2]
# Out:
# 0    MaryamSkaik@gmail.com
# 1        Tialulu@email.com
# Name: email, dtype: object

# %%
df.iloc[[0,1], [1,2]]
# Out:
#     last                  email
# 0  Skaik  MaryamSkaik@gmail.com
# 1   lulu      Tialulu@email.com

# %%
df.loc[[0,1]]
# Out:
#     first   last                  email
# 0  Maryam  Skaik  MaryamSkaik@gmail.com
# 1     Tia   lulu      Tialulu@email.com

# %%
# can use name of columns as index with loc
df.loc[[0,1], 'email']
# Out:
# 0    MaryamSkaik@gmail.com
# 1        Tialulu@email.com
# Name: email, dtype: object
