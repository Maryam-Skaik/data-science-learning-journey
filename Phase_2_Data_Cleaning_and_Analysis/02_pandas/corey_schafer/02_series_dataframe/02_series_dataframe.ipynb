# %% [markdown]
# # DataFrame and Series Basics - Selecting Rows and Columns

# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')
schema_pd = pd.read_csv('data/survey_results_schema.csv')
# Out:
# C:\Users\Maryam\AppData\Local\Temp\ipykernel_14604\1988893661.py:1: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/survey_results_public.csv')

# %%
df.head(11)
# Out:
#     ResponseId                      MainBranch              Age  \
# 0            1  I am a developer by profession  25-34 years old
# 1            2  I am a developer by profession  25-34 years old
# 2            3  I am a developer by profession  35-44 years old
# 3            4  I am a developer by profession  35-44 years old
# 4            5  I am a developer by profession  35-44 years old
# 5            6  I am a developer by profession  45-54 years old
# 6            7  I am a developer by profession  25-34 years old
# 7            8  I am a developer by profession  35-44 years old
# 8            9  I am a developer by profession  25-34 years old
# 9           10  I am a developer by profession  25-34 years old
# 10          11  I am a developer by profession  25-34 years old
#
#                                               EdLevel  \
# 0     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1                 Associate degree (A.A., A.S., etc.)
# ...

# %%
schema_pd
# Out:
#         qid            qname  \
# 0     QID18    TechEndorse_1
# 1     QID18    TechEndorse_2
# 2     QID18    TechEndorse_3
# 3     QID18    TechEndorse_4
# 4     QID18    TechEndorse_5
# ..      ...              ...
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  \
# 0    What attracts you to a technology or causes yo...   RO
# 1    What attracts you to a technology or causes yo...   RO
# 2    What attracts you to a technology or causes yo...   RO
# 3    What attracts you to a technology or causes yo...   RO
# 4    What attracts you to a technology or causes yo...   RO
# ..                                                 ...  ...
# 134  Was the tool or tools for AI agent observabili...   TE
# 135  You indicated you use or develop AI agents as ...   MC
# 136  Was the out-of-the-box agents, copilots or ass...   TE
# ...

# %%
df.shape
# Out:
# (49191, 172)

# %%
list(df.columns)
# Out:
# ['ResponseId',
#  'MainBranch',
#  'Age',
#  'EdLevel',
#  'Employment',
#  'EmploymentAddl',
#  'WorkExp',
#  'LearnCodeChoose',
#  'LearnCode',
#  'LearnCodeAI',
#  'AILearnHow',
#  'YearsCode',
#  'DevType',
#  'OrgSize',
#  'ICorPM',
#  'RemoteWork',
#  'PurchaseInfluence',
#  'TechEndorseIntro',
#  'TechEndorse_1',
#  'TechEndorse_2',
#  'TechEndorse_3',
#  'TechEndorse_4',
#  'TechEndorse_5',
#  'TechEndorse_6',
#  'TechEndorse_7',
#  'TechEndorse_8',
#  'TechEndorse_9',
#  'TechEndorse_13',
#  'TechEndorse_13_TEXT',
#  'TechOppose_1',
#  'TechOppose_2',
#  'TechOppose_3',
#  'TechOppose_5',
#  'TechOppose_7',
#  'TechOppose_9',
#  'TechOppose_11',
#  'TechOppose_13',
#  'TechOppose_16',
#  'TechOppose_15',
#  'TechOppose_15_TEXT',
#  'Industry',
#  'JobSatPoints_1',
#  'JobSatPoints_2',
#  'JobSatPoints_3',
#  'JobSatPoints_4',
#  'JobSatPoints_5',
#  'JobSatPoints_6',
#  'JobSatPoints_7',
#  'JobSatPoints_8',
#  'JobSatPoints_9',
#  'JobSatPoints_10',
#  'JobSatPoints_11',
# ...

# %%
df['AIThreat']
# Out:
# 0        I'm not sure
# 1        I'm not sure
# 2                  No
# 3                  No
# 4                  No
#              ...
# 49186             NaN
# 49187             NaN
# 49188              No
# 49189             NaN
# 49190             NaN
# Name: AIThreat, Length: 49191, dtype: object

# %%
df['AIThreat'].value_counts()
# Out:
# AIThreat
# No              22958
# I'm not sure     7700
# Yes              5420
# Name: count, dtype: int64

# %%
df.loc[0, 'AIThreat']
# Out:
# "I'm not sure"

# %%
df.loc[[0,2,3,4], 'AIThreat']
# Out:
# 0    I'm not sure
# 2              No
# 3              No
# 4              No
# Name: AIThreat, dtype: object

# %%
# when we use slicing, we don't use []
df.loc[0:20, 'AIThreat']
# Out:
# 0     I'm not sure
# 1     I'm not sure
# 2               No
# 3               No
# 4               No
# 5     I'm not sure
# 6              Yes
# 7              Yes
# 8               No
# 9               No
# 10              No
# 11              No
# 12    I'm not sure
# 13              No
# 14    I'm not sure
# 15             Yes
# 16             NaN
# 17             Yes
# 18              No
# 19              No
# 20              No
# Name: AIThreat, dtype: object

# %%
df.loc[0:20, 'AIThreat':'Currency']
# Out:
#         AIThreat                                            NewRole  \
# 0   I'm not sure  I have neither consider or transitioned into a...
# 1   I'm not sure  I have transitioned into a new career and/or i...
# 2             No  I have transitioned into a new career and/or i...
# 3             No  I have neither consider or transitioned into a...
# 4             No  I have neither consider or transitioned into a...
# 5   I'm not sure  I have somewhat considered changing my career ...
# 6            Yes  I have somewhat considered changing my career ...
# 7            Yes  I have strongly considered changing my career ...
# 8             No  I have transitioned into a new career and/or i...
# 9             No  I have somewhat considered changing my career ...
# 10            No  I have neither consider or transitioned into a...
# 11            No  I have neither consider or transitioned into a...
# 12  I'm not sure  I have neither consider or transitioned into a...
# ...
