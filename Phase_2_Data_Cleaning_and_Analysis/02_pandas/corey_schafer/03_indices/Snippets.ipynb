# %%
people = {
    "first": ["Maryam", 'Tia', 'Tima'], 
    "last": ["Skaik", 'lulu', 'lulu'], 
    "email": ["MaryamSkaik@gmail.com", 'Tialulu@email.com', 'Timalulu@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)
df
# Out:
#     first   last                  email
# 0  Maryam  Skaik  MaryamSkaik@gmail.com
# 1     Tia   lulu      Tialulu@email.com
# 2    Tima   lulu     Timalulu@email.com

# %%
df['email']
# Out:
# 0    MaryamSkaik@gmail.com
# 1        Tialulu@email.com
# 2       Timalulu@email.com
# Name: email, dtype: object

# %%
df.set_index('email')
# Out:
#                         first   last
# email
# MaryamSkaik@gmail.com  Maryam  Skaik
# Tialulu@email.com         Tia   lulu
# Timalulu@email.com       Tima   lulu

# %%
df # didn't change
# Out:
#                         first   last
# email
# MaryamSkaik@gmail.com  Maryam  Skaik
# Tialulu@email.com         Tia   lulu
# Timalulu@email.com       Tima   lulu

# %%
df.set_index('email', inplace=True)
df
# Out:
#                         first   last
# email
# MaryamSkaik@gmail.com  Maryam  Skaik
# Tialulu@email.com         Tia   lulu
# Timalulu@email.com       Tima   lulu

# %%
df.index
# Out:
# Index(['MaryamSkaik@gmail.com', 'Tialulu@email.com', 'Timalulu@email.com'], dtype='object', name='email')

# %%
# this give benifit since email is unique so help identify rows
df.loc['MaryamSkaik@gmail.com', 'last']
# Out:
# 'Skaik'

# %%
df.loc[0] # gives error, since index is not interger, so we have to use iloc
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.loc[0]
#
# ...

# %%
df.iloc[0]
# Out:
# first    Maryam
# last      Skaik
# Name: MaryamSkaik@gmail.com, dtype: object

# %%
# also we can reset index
df.reset_index(inplace=True)
df
# Out:
#                    email   first   last
# 0  MaryamSkaik@gmail.com  Maryam  Skaik
# 1      Tialulu@email.com     Tia   lulu
# 2     Timalulu@email.com    Tima   lulu
