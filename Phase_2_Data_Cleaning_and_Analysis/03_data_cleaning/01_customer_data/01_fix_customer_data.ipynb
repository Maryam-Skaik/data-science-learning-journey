# %% [markdown]
# #  Fixing Messy Credit Customer Data

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
data = pd.read_csv('./data/credit_customers.csv')
data
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0       6.0  critical/other existing credit
# 1          0<=X<200      48.0                   existing paid
# 2       no checking      12.0  critical/other existing credit
# 3                <0      42.0                   existing paid
# 4                <0      24.0              delayed previously
# ..              ...       ...                             ...
# 995     no checking      12.0                   existing paid
# 996              <0      30.0                   existing paid
# 997     no checking      12.0                   existing paid
# 998              <0      45.0                   existing paid
# 999        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv         1169.0  no known savings         >=7
# 1               radio/tv         5951.0              <100      1<=X<4
# ...

# %%
data.columns
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         1000 non-null   object
#  1   duration                1000 non-null   float64
#  2   credit_history          1000 non-null   object
#  3   purpose                 1000 non-null   object
#  4   credit_amount           1000 non-null   float64
#  5   savings_status          1000 non-null   object
#  6   employment              1000 non-null   object
#  7   installment_commitment  1000 non-null   float64
#  8   personal_status         1000 non-null   object
#  9   other_parties           1000 non-null   object
#  10  residence_since         1000 non-null   float64
#  11  property_magnitude      1000 non-null   object
#  12  age                     1000 non-null   float64
#  13  other_payment_plans     1000 non-null   object
# ...

# %% [markdown]
# ## Dtat cleaning steps:
# 1. Deleting redundant columns.
# 2. Renaming the columns.
# 3. Dropping duplicates
# 4. Remove the NaN from the dataset
# 5. Check for some more Transformation

# %%
data.drop(columns= ['checking_status', 'duration', 'credit_history', 'purpose', 'employment', 'installment_commitment', 'personal_status', 'other_parties',
       'residence_since', 'property_magnitude', 'other_payment_plans', 'num_dependents', 'savings_status'], inplace=True)

# %%
data
# Out:
#      credit_amount   age   housing  existing_credits  \
# 0           1169.0  67.0       own               2.0
# 1           5951.0  22.0       own               1.0
# 2           2096.0  49.0       own               1.0
# 3           7882.0  45.0  for free               1.0
# 4           4870.0  53.0  for free               2.0
# ..             ...   ...       ...               ...
# 995         1736.0  31.0       own               1.0
# 996         3857.0  40.0       own               1.0
# 997          804.0  38.0       own               1.0
# 998         1845.0  23.0  for free               1.0
# 999         4576.0  27.0       own               1.0
#
#                            job own_telephone foreign_worker class
# 0                      skilled           yes            yes  good
# 1                      skilled          none            yes   bad
# 2           unskilled resident          none            yes  good
# ...

# %%
data_new_column_name = []
for i in data.columns:
    data_new_column_name.append(i.capitalize())

data_new_column_name
# Out:
# ['Credit_amount',
#  'Age',
#  'Housing',
#  'Existing_credits',
#  'Job',
#  'Own_telephone',
#  'Foreign_worker',
#  'Class']

# %%
data.columns = data_new_column_name
data
# Out:
#      Credit_amount   Age   Housing  Existing_credits  \
# 0           1169.0  67.0       own               2.0
# 1           5951.0  22.0       own               1.0
# 2           2096.0  49.0       own               1.0
# 3           7882.0  45.0  for free               1.0
# 4           4870.0  53.0  for free               2.0
# ..             ...   ...       ...               ...
# 995         1736.0  31.0       own               1.0
# 996         3857.0  40.0       own               1.0
# 997          804.0  38.0       own               1.0
# 998         1845.0  23.0  for free               1.0
# 999         4576.0  27.0       own               1.0
#
#                            Job Own_telephone Foreign_worker Class
# 0                      skilled           yes            yes  good
# 1                      skilled          none            yes   bad
# 2           unskilled resident          none            yes  good
# ...

# %%
data.duplicated().sum() # there is no duplicates
# Out:
# np.int64(0)

# %%
data.isna().sum() # same we don't have missong values
# Out:
# Credit_amount       0
# Age                 0
# Housing             0
# Existing_credits    0
# Job                 0
# Own_telephone       0
# Foreign_worker      0
# Class               0
# dtype: int64

# %%
data['Class'].nunique()
# Out:
# 2

# %%
data['Class'].unique()
# Out:
# array(['good', 'bad'], dtype=object)

# %%
# we will replace good and bad with ones and zeros
data['Class'].apply(lambda x : 1 if x == 'good' else 0)
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 995    1
# 996    1
# 997    1
# 998    0
# 999    1
# Name: Class, Length: 1000, dtype: int64

# %%
data['Class'] = data['Class'].apply(lambda x : 1 if x == 'good' else 0)
data
# Out:
#      Credit_amount   Age   Housing  Existing_credits  \
# 0           1169.0  67.0       own               2.0
# 1           5951.0  22.0       own               1.0
# 2           2096.0  49.0       own               1.0
# 3           7882.0  45.0  for free               1.0
# 4           4870.0  53.0  for free               2.0
# ..             ...   ...       ...               ...
# 995         1736.0  31.0       own               1.0
# 996         3857.0  40.0       own               1.0
# 997          804.0  38.0       own               1.0
# 998         1845.0  23.0  for free               1.0
# 999         4576.0  27.0       own               1.0
#
#                            Job Own_telephone Foreign_worker  Class
# 0                      skilled           yes            yes      1
# 1                      skilled          none            yes      0
# 2           unskilled resident          none            yes      1
# ...

# %%
# change Existing_credits data type
type(data['Existing_credits'][0])
# Out:
# numpy.float64

# %%
data['Existing_credits'].astype(int)
# Out:
# 0      2
# 1      1
# 2      1
# 3      1
# 4      2
#       ..
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: Existing_credits, Length: 1000, dtype: int64

# %%
data['Existing_credits'] = data['Existing_credits'].astype(int)

# %%
data
# Out:
#      Credit_amount   Age   Housing  Existing_credits  \
# 0           1169.0  67.0       own                 2
# 1           5951.0  22.0       own                 1
# 2           2096.0  49.0       own                 1
# 3           7882.0  45.0  for free                 1
# 4           4870.0  53.0  for free                 2
# ..             ...   ...       ...               ...
# 995         1736.0  31.0       own                 1
# 996         3857.0  40.0       own                 1
# 997          804.0  38.0       own                 1
# 998         1845.0  23.0  for free                 1
# 999         4576.0  27.0       own                 1
#
#                            Job Own_telephone Foreign_worker  Class
# 0                      skilled           yes            yes      1
# 1                      skilled          none            yes      0
# 2           unskilled resident          none            yes      1
# ...

# %%
data.to_excel('cleaned_data.xlsx', index = False)

# %%
data.to_csv('cleaned_csv_data.csv', index=False)
